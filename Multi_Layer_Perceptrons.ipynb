# %% [markdown]
# <a href="https://colab.research.google.com/github/dipanjannC/Deep-Learning/blob/master/Multi_Layer_Perceptrons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Initializations

# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf

# %%
mnist = input_data.read_data_sets("MNIST_data/",one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-4-758d29429358>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import time
# https://gist.github.com/greydanus/f6eee59eaf1d90fcb3b534a25362cea4
# https://stackoverflow.com/a/14434334
# this function is used to update the plots for each epoch and error
def plt_dynamic(x, y, y_1, ax, ticks,title, colors=['b']):
    ax.plot(x, y, 'b', label="Train Loss")
    ax.plot(x, y_1, 'r', label="Test Loss")
    if len(x)==1:
        plt.legend()
        plt.title(title)
    plt.yticks(ticks)
    fig.canvas.draw()

# %%
print("number of datapoints: ", mnist.train.images.shape[0]," number of pixels in each image: ",mnist.train.images.shape[1])
print("number of datapoints: ", mnist.train.labels.shape[0]," number of labels in dataset: ",mnist.train.labels.shape[1])
# Out:
# number of datapoints:  55000  number of pixels in each image:  784
# number of datapoints:  55000  number of labels in dataset:  10

# %%
# Network Parameters
n_input = 784
n_classes = 10
n_hidden_1 = 512 # number of neurons in 1st Layer
n_hidden_2 = 128 # number of neurons in 2nd layer

# %% [markdown]
# So , our architecture is iike,
#
#     F.C        F.C      SMC(softmax classifier)
# 728  ---------->  512  ----------->  128 ----------->   10

# %%
# Initializing the Placeholders
x = tf.placeholder(tf.float32,[None, 784])  # placeholder for inputs
y_ = tf.placeholder(tf.float32,[None, 10])  # placeholder for actual y_i

#placeholder for dropouts
keep_prob = tf.placeholder(tf.float32)
keep_prob_input = tf.placeholder(tf.float32)

# %%
# Weight initialization

# https://arxiv.org/pdf/1707.09725.pdf#page=95
# https://www.tensorflow.org/api_docs/python/tf/random_normal
# Outputs random values from a normal distribution mean=0 std=1

# If we sample weights from a normal distribution N(0,σ) we satisfy this condition with σ=√(2/(ni+ni+1). 
# h1 =>  σ=√(2/(fan_in+fan_out+1) = 0.039  => N(0,σ) = N(0,0.039)
# h2 =>  σ=√(2/(fan_in+fan_out+1) = 0.055  => N(0,σ) = N(0,0.055)
# out =>  σ=√(2/(fan_in+fan_out+1) = 0.120  => N(0,σ) = N(0,0.120)
# SGD: Xavier/Glorot Normal initialization.
weights_sgd = {
    'h1': tf.Variable(tf.random_normal([n_input, n_hidden_1],stddev=0.039, mean=0)),    #784x512 # sqrt(2/(784+512)) = 0.039
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2],stddev=0.055, mean=0)), #512x128 # sqrt(2/(512+128)) = 0.055
    'out': tf.Variable(tf.random_normal([n_hidden_2, n_classes],stddev=0.120, mean=0))  #128x10
}

# https://arxiv.org/pdf/1707.09725.pdf#page=95
# for relu lates
# If we sample weights from a normal distribution N(0,σ) we satisfy this condition with σ=√(2/(ni). 
# h1 =>  σ=√(2/(fan_in+1) = 0.062  => N(0,σ) = N(0,0.062)
# h2 =>  σ=√(2/(fan_in+1) = 0.125  => N(0,σ) = N(0,0.125)
# out =>  σ=√(2/(fan_in+1) = 0.120  => N(0,σ) = N(0,0.120)
# He Normal initialization.
weights_relu = {
    'h1': tf.Variable(tf.random_normal([n_input, n_hidden_1],stddev=0.062, mean=0)),    #784x512
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2],stddev=0.125, mean=0)), #512x128
    'out': tf.Variable(tf.random_normal([n_hidden_2, n_classes],stddev=0.120, mean=0))  #128x10
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),             #512x1
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),             #128x1
    'out': tf.Variable(tf.random_normal([n_classes]))              #10x1
}
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Parameters
training_epochs = 50
learning_rate = 0.001
batch_size = 100
display_step = 1 #i.e after how many steps you want to display your plot,here after each epoch we will display

# %% [markdown]
# # Model 1 : input (784) - sigmoid(512) - sigmoid(128) - softmax(output 10)

# %%
# Create model
def multilayer_perceptron(x, weights, biases):
    # Use tf.matmul instead of "*" because tf.matmul can change it's dimensions on the fly (broadcast)
    print( 'x:', x.get_shape(), 'W[h1]:', weights['h1'].get_shape(), 'b[h1]:', biases['b1'].get_shape())        
    
    # Hidden layer with Sigmoid activation
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1']) #(x*weights['h1']) + biases['b1']
    layer_1 = tf.nn.sigmoid(layer_1)
    print( 'layer_1:', layer_1.get_shape(), 'W[h2]:', weights['h2'].get_shape(), 'b[h2]:', biases['b2'].get_shape())        
    
    # Hidden layer with Sigmoid activation
    layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2']) # (layer_1 * weights['h2']) + biases['b2'] 
    layer_2 = tf.nn.sigmoid(layer_2)
    print( 'layer_2:', layer_2.get_shape(), 'W[out]:', weights['out'].get_shape(), 'b3:', biases['out'].get_shape())        
    
    # Output layer with Sigmoid activation
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out'] # (layer_2 * weights['out']) + biases['out']    
    out_layer = tf.nn.sigmoid(out_layer)
    print('out_layer:',out_layer.get_shape())

    return out_layer

# %% [markdown]
# Model 1 with Adam Optimizer

# %%
# Since we are using sigmoid activations in hiden layers we will be using weights that are initalized as weights_sgd
# Computer y_i hat i.e the predicted value
y_sgd = multilayer_perceptron(x,weights_sgd,biases)

#calculating the log loss value i.e cross entropy
cost_sgd = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = y_sgd, labels = y_))

# Initializting the Optimizers
optimizer_adam = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost_sgd)
optimizer_sgdc = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost_sgd)


with tf.Session() as sess:
    # initializing all the global variables
    tf.global_variables_initializer().run()
    fig,ax = plt.subplots(1,1)
    ax.set_xlabel('epoch') ; ax.set_ylabel('Soft Max Cross Entropy loss')
    xs, ytrs, ytes = [], [], []
    for epoch in range(training_epochs):
        train_avg_cost = 0.   
        test_avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size) # fetching the no. of batches according to batch_size we initialized earlier

        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)

            # here c: corresponds to the parameter cost_sgd
            # w : correspondse to the parameter weights_sgd
            # c = sess.run() return the cost after every bath during train
            # w = sess.run() return the weights that are modified after every batch through Back prop
            # w is dict w = {'h1': updated h1 weight vector after the current batch,
            #                'h2': updated h2 weight vector after the current batch, 
            #                'out': updated output weight vector after the current batch, 
            #                }
            # you check these w matrix for every iteration, and check whats happening during back prop
            #
            # note: sess.run() returns parameter values based on the input parameters
            # _, c, w = sess.run([optimizer_adam, cost_sgd,weights_sgd]) it returns three parameters
            # _, c = sess.run([optimizer_adam, cost_sgd ]) it returns two parameters
            # _ = sess.run([optimizer_adam]) it returns one paramter (for the input optimizer it return none)
            # c = sess.run([cost_sgd]) it returns one paramter (for the input cost return error after the batch)

            # feed_dict={x: batch_xs, y_: batch_ys} here x, y_ should be placeholders
            # x, y_ are the input parameters on which the models gets trained

            # here we use AdamOptimizer
            _, c, w = sess.run([optimizer_adam, cost_sgd,weights_sgd], feed_dict={x: batch_xs, y_: batch_ys})
            train_avg_cost += c / total_batch # calulating average training loss after each iteration(epoch)
            c = sess.run(cost_sgd, feed_dict={x: mnist.test.images, y_: mnist.test.labels})
            test_avg_cost += c / total_batch # calulating average training loss after each iteration(epoch)

        xs.append(epoch)
        ytrs.append(train_avg_cost)
        ytes.append(test_avg_cost)
        plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.3, 1.8, step=0.04), "input-sigmoid(512)-sigmoid(128)-sigmoid(output)-AdamOptimizer")

        if epoch%display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "train cost={:.9f}".format(train_avg_cost), "test cost={:.9f}".format(test_avg_cost))
    plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.3, 1.8, step=0.04), "input-sigmoid(512)-sigmoid(128)-sigmoid(output)-AdamOptimizer")

    # we are calculating the final accuracy on the test data
    correct_prediction = tf.equal(tf.argmax(y_sgd,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# x: (?, 784) W[h1]: (784, 512) b[h1]: (512,)
# layer_1: (?, 512) W[h2]: (512, 128) b[h2]: (128,)
# layer_2: (?, 128) W[out]: (128, 10) b3: (10,)
# out_layer: (?, 10)
# Epoch: 0001 train cost=1.682941594 test cost=1.676739588
# Epoch: 0002 train cost=1.538383644 test cost=1.536499198
# Epoch: 0003 train cost=1.516285429 test cost=1.516714223
# Epoch: 0004 train cost=1.504306501 test cost=1.505756942
# Epoch: 0005 train cost=1.495986246 test cost=1.498500832
# Epoch: 0006 train cost=1.489618614 test cost=1.493705590
# Epoch: 0007 train cost=1.484975125 test cost=1.490166647
# Epoch: 0008 train cost=1.481422061 test cost=1.487790055
# Epoch: 0009 train cost=1.478575771 test cost=1.485733355
# Epoch: 0010 train cost=1.476058757 test cost=1.484414918
# Epoch: 0011 train cost=1.474140810 test cost=1.483432052
# Epoch: 0012 train cost=1.472469109 test cost=1.482476808
# Epoch: 0013 train cost=1.471253896 test cost=1.482072009
# Epoch: 0014 train cost=1.470228230 test cost=1.481680430
# Epoch: 0015 train cost=1.469267078 test cost=1.481633327
# Epoch: 0016 train cost=1.468294699 test cost=1.481299715
# Epoch: 0017 train cost=1.467557364 test cost=1.480899447
# Epoch: 0018 train cost=1.466911943 test cost=1.480811645
# Epoch: 0019 train cost=1.466266738 test cost=1.480263410
# Epoch: 0020 train cost=1.466055585 test cost=1.480381988
# Epoch: 0021 train cost=1.465652669 test cost=1.480519126
# Epoch: 0022 train cost=1.465357198 test cost=1.480613761
# Epoch: 0023 train cost=1.465114465 test cost=1.480731448
# Epoch: 0024 train cost=1.464870861 test cost=1.480987668
# Epoch: 0025 train cost=1.465327208 test cost=1.480789606
# Epoch: 0026 train cost=1.464503691 test cost=1.480841666
# Epoch: 0027 train cost=1.464421657 test cost=1.480871884
# Epoch: 0028 train cost=1.464904290 test cost=1.480552015
# Epoch: 0029 train cost=1.464153756 test cost=1.480324412
# Epoch: 0030 train cost=1.464373003 test cost=1.480429038
# Epoch: 0031 train cost=1.463770767 test cost=1.480009640
# Epoch: 0032 train cost=1.463773603 test cost=1.480380417
# Epoch: 0033 train cost=1.464417555 test cost=1.480926221
# Epoch: 0034 train cost=1.463737363 test cost=1.480057773
# Epoch: 0035 train cost=1.464048922 test cost=1.480330759
# Epoch: 0036 train cost=1.463738313 test cost=1.480122780
# Epoch: 0037 train cost=1.463548761 test cost=1.479790859
# Epoch: 0038 train cost=1.463763268 test cost=1.479964185
# Epoch: 0039 train cost=1.463622603 test cost=1.479820975
# Epoch: 0040 train cost=1.463226316 test cost=1.479336784
# Epoch: 0041 train cost=1.463456617 test cost=1.479563129
# Epoch: 0042 train cost=1.463210438 test cost=1.478993087
# Epoch: 0043 train cost=1.463667696 test cost=1.479659577
# Epoch: 0044 train cost=1.463580203 test cost=1.479884903
# Epoch: 0045 train cost=1.463130680 test cost=1.479209472
# Epoch: 0046 train cost=1.463343211 test cost=1.479679087
# Epoch: 0047 train cost=1.463521476 test cost=1.479831500
# Epoch: 0048 train cost=1.463248908 test cost=1.478998889
# Epoch: 0049 train cost=1.463021111 test cost=1.478639287
# Epoch: 0050 train cost=1.463166281 test cost=1.479057719
# Epoch: 0051 train cost=1.462935871 test cost=1.478824414
# Epoch: 0052 train cost=1.463258927 test cost=1.480008315
# Epoch: 0053 train cost=1.463251598 test cost=1.479993675
# Epoch: 0054 train cost=1.462938199 test cost=1.479079332
# Epoch: 0055 train cost=1.462858350 test cost=1.479308928
# Epoch: 0056 train cost=1.462809785 test cost=1.479209700
# Epoch: 0057 train cost=1.462790944 test cost=1.479166078
# Epoch: 0058 train cost=1.462787897 test cost=1.479093847
# Epoch: 0059 train cost=1.463507203 test cost=1.479757074
# Epoch: 0060 train cost=1.463396820 test cost=1.479302944
# Epoch: 0061 train cost=1.462859743 test cost=1.479120564
# Epoch: 0062 train cost=1.462731714 test cost=1.478972243
# Epoch: 0063 train cost=1.462709075 test cost=1.478847529
# Epoch: 0064 train cost=1.462706510 test cost=1.478790617
# Epoch: 0065 train cost=1.463417166 test cost=1.479749906
# Epoch: 0066 train cost=1.463001789 test cost=1.479726478
# Epoch: 0067 train cost=1.462877967 test cost=1.479089723
# Epoch: 0068 train cost=1.462778704 test cost=1.479552042
# Epoch: 0069 train cost=1.462729837 test cost=1.479904852
# Epoch: 0070 train cost=1.462702536 test cost=1.479272977
# Epoch: 0071 train cost=1.462972325 test cost=1.479495918
# Epoch: 0072 train cost=1.463123710 test cost=1.479368640
# Epoch: 0073 train cost=1.462722113 test cost=1.478895953
# Epoch: 0074 train cost=1.462656378 test cost=1.479094922
# Epoch: 0075 train cost=1.462650900 test cost=1.478959805
# Epoch: 0076 train cost=1.462650175 test cost=1.478975938
# Epoch: 0077 train cost=1.462647153 test cost=1.478966271
# Epoch: 0078 train cost=1.462631225 test cost=1.478893672
# Epoch: 0079 train cost=1.462630910 test cost=1.478753238
# Epoch: 0080 train cost=1.463924875 test cost=1.480171909
# Epoch: 0081 train cost=1.462784419 test cost=1.479161767
# Epoch: 0082 train cost=1.462670432 test cost=1.479095173
# Epoch: 0083 train cost=1.462620465 test cost=1.479138353
# Epoch: 0084 train cost=1.462640048 test cost=1.479172059
# Epoch: 0085 train cost=1.462850694 test cost=1.479821035
# Epoch: 0086 train cost=1.462857049 test cost=1.479876047
# Epoch: 0087 train cost=1.462775665 test cost=1.479941851
# Epoch: 0088 train cost=1.462697300 test cost=1.479785857
# Epoch: 0089 train cost=1.462622495 test cost=1.479961377
# Epoch: 0090 train cost=1.462578588 test cost=1.479417449
# Epoch: 0091 train cost=1.462576804 test cost=1.479025338
# Epoch: 0092 train cost=1.463177819 test cost=1.479982987
# Epoch: 0093 train cost=1.462610721 test cost=1.479001541
# Epoch: 0094 train cost=1.462539916 test cost=1.479158794
# Epoch: 0095 train cost=1.462534701 test cost=1.479351459
# Epoch: 0096 train cost=1.462528601 test cost=1.479368678
# Epoch: 0097 train cost=1.462527778 test cost=1.479257174
# Epoch: 0098 train cost=1.462527277 test cost=1.479143121
# Epoch: 0099 train cost=1.462527068 test cost=1.479119196
# Epoch: 0100 train cost=1.462526898 test cost=1.479078905
# Accuracy: 0.9817

# %%
# Plot weight distriubtion at the end of training.

import seaborn as sns
h1_w = w['h1'].flatten().reshape(-1,1)
h2_w = w['h2'].flatten().reshape(-1,1)
out_w = w['out'].flatten().reshape(-1,1)


fig = plt.figure()
plt.subplot(1, 3, 1)
plt.title("Weight matrix")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Weight matrix ")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Weight matrix ")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# **Model 1 with Gradient Decent Optimizer**

# %%
# We can now launch the model in an InteractiveSession

# Note: make sure you initialize variables

with tf.Session() as sess:
    tf.global_variables_initializer().run()
    fig,ax = plt.subplots(1,1)
    ax.set_xlabel('epoch') ; ax.set_ylabel('Soft Max Cross Entropy loss')
    xs, ytrs, ytes = [], [], []
    for epoch in range(training_epochs):
        train_avg_cost = 0.
        test_avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)

        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)

            # here we use GradientDescentOptimizer
            _, c, w = sess.run([optimizer_sgdc, cost_sgd, weights_sgd], feed_dict={x: batch_xs, y_: batch_ys})
            train_avg_cost += c / total_batch
            c = sess.run(cost_sgd, feed_dict={x: mnist.test.images, y_: mnist.test.labels})
            test_avg_cost += c / total_batch

        xs.append(epoch)
        ytrs.append(train_avg_cost)
        ytes.append(test_avg_cost)
        plt_dynamic(xs, ytrs, ytes, ax, np.arange(2, 2.6, step=0.05), "input-sigmoid(512)-sigmoid(128)-sigmoid(output)-GradientDescentOptimizer")

        if epoch%display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "train cost={:.9f}".format(train_avg_cost), "test cost={:.9f}".format(test_avg_cost))
    plt_dynamic(xs, ytrs, ytes, ax, np.arange(2, 2.6, step=0.05), "input-sigmoid(512)-sigmoid(128)-sigmoid(output)-GradientDescentOptimizer")

    # we are calculating the final accuracy on the test data
    correct_prediction = tf.equal(tf.argmax(y_sgd,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# Epoch: 0001 train cost=2.321564540 test cost=2.321150202
# Epoch: 0002 train cost=2.318521373 test cost=2.318157343
# Epoch: 0003 train cost=2.315810137 test cost=2.315517844
# Epoch: 0004 train cost=2.313424408 test cost=2.313203239
# Epoch: 0005 train cost=2.311333858 test cost=2.311149142
# Epoch: 0006 train cost=2.309496613 test cost=2.309346313
# Epoch: 0007 train cost=2.307867411 test cost=2.307755907
# Epoch: 0008 train cost=2.306409356 test cost=2.306304021
# Epoch: 0009 train cost=2.305092844 test cost=2.305030156
# Epoch: 0010 train cost=2.303899262 test cost=2.303813533
# Epoch: 0011 train cost=2.302816279 test cost=2.302718572
# Epoch: 0012 train cost=2.301831965 test cost=2.301750970
# Epoch: 0013 train cost=2.300937148 test cost=2.300834191
# Epoch: 0014 train cost=2.300127413 test cost=2.300014296
# Epoch: 0015 train cost=2.299395790 test cost=2.299252249
# Epoch: 0016 train cost=2.298738532 test cost=2.298571920
# Epoch: 0017 train cost=2.298147681 test cost=2.297952731
# Epoch: 0018 train cost=2.297613135 test cost=2.297386894
# Epoch: 0019 train cost=2.297126886 test cost=2.296877471
# Epoch: 0020 train cost=2.296680126 test cost=2.296406294
# Epoch: 0021 train cost=2.296265528 test cost=2.295964683
# Epoch: 0022 train cost=2.295873640 test cost=2.295556330
# Epoch: 0023 train cost=2.295501189 test cost=2.295161662
# Epoch: 0024 train cost=2.295142510 test cost=2.294777470
# Epoch: 0025 train cost=2.294794208 test cost=2.294423347
# Epoch: 0026 train cost=2.294453392 test cost=2.294064053
# Epoch: 0027 train cost=2.294117421 test cost=2.293703821
# Epoch: 0028 train cost=2.293784975 test cost=2.293361636
# Epoch: 0029 train cost=2.293453683 test cost=2.293002984
# Epoch: 0030 train cost=2.293125329 test cost=2.292677001
# Epoch: 0031 train cost=2.292795767 test cost=2.292337239
# Epoch: 0032 train cost=2.292465594 test cost=2.291993745
# Epoch: 0033 train cost=2.292134398 test cost=2.291653659
# Epoch: 0034 train cost=2.291803384 test cost=2.291301772
# Epoch: 0035 train cost=2.291469642 test cost=2.290964771
# Epoch: 0036 train cost=2.291134550 test cost=2.290616875
# Epoch: 0037 train cost=2.290797670 test cost=2.290272993
# Epoch: 0038 train cost=2.290458977 test cost=2.289919460
# Epoch: 0039 train cost=2.290117664 test cost=2.289564238
# Epoch: 0040 train cost=2.289774823 test cost=2.289207489
# Epoch: 0041 train cost=2.289429480 test cost=2.288859224
# Epoch: 0042 train cost=2.289081226 test cost=2.288499696
# Epoch: 0043 train cost=2.288731119 test cost=2.288138711
# Epoch: 0044 train cost=2.288378189 test cost=2.287775103
# Epoch: 0045 train cost=2.288021871 test cost=2.287411599
# Epoch: 0046 train cost=2.287663919 test cost=2.287043044
# Epoch: 0047 train cost=2.287302453 test cost=2.286673053
# Epoch: 0048 train cost=2.286937976 test cost=2.286292459
# Epoch: 0049 train cost=2.286570187 test cost=2.285922900
# Epoch: 0050 train cost=2.286199627 test cost=2.285542485
# Epoch: 0051 train cost=2.285826515 test cost=2.285151377
# Epoch: 0052 train cost=2.285449222 test cost=2.284770027
# Epoch: 0053 train cost=2.285069395 test cost=2.284380173
# Epoch: 0054 train cost=2.284685209 test cost=2.283981590
# Epoch: 0055 train cost=2.284298151 test cost=2.283589152
# Epoch: 0056 train cost=2.283907386 test cost=2.283180366
# Epoch: 0057 train cost=2.283512267 test cost=2.282781885
# Epoch: 0058 train cost=2.283113493 test cost=2.282372105
# Epoch: 0059 train cost=2.282710511 test cost=2.281963414
# Epoch: 0060 train cost=2.282304469 test cost=2.281535757
# Epoch: 0061 train cost=2.281893313 test cost=2.281127125
# Epoch: 0062 train cost=2.281479163 test cost=2.280689754
# Epoch: 0063 train cost=2.281060153 test cost=2.280272335
# Epoch: 0064 train cost=2.280636574 test cost=2.279828439
# Epoch: 0065 train cost=2.280208695 test cost=2.279384778
# Epoch: 0066 train cost=2.279775898 test cost=2.278948682
# Epoch: 0067 train cost=2.279339030 test cost=2.278500741
# Epoch: 0068 train cost=2.278896486 test cost=2.278050893
# Epoch: 0069 train cost=2.278450201 test cost=2.277586519
# Epoch: 0070 train cost=2.277997427 test cost=2.277127512
# Epoch: 0071 train cost=2.277540361 test cost=2.276653729
# Epoch: 0072 train cost=2.277078350 test cost=2.276171335
# Epoch: 0073 train cost=2.276610667 test cost=2.275707240
# Epoch: 0074 train cost=2.276137298 test cost=2.275204777
# Epoch: 0075 train cost=2.275658953 test cost=2.274733351
# Epoch: 0076 train cost=2.275174474 test cost=2.274227627
# Epoch: 0077 train cost=2.274684853 test cost=2.273717456
# Epoch: 0078 train cost=2.274189373 test cost=2.273205914
# Epoch: 0079 train cost=2.273686140 test cost=2.272699835
# Epoch: 0080 train cost=2.273178508 test cost=2.272176253
# Epoch: 0081 train cost=2.272664129 test cost=2.271644532
# Epoch: 0082 train cost=2.272143000 test cost=2.271113611
# Epoch: 0083 train cost=2.271615998 test cost=2.270578122
# Epoch: 0084 train cost=2.271082051 test cost=2.270020327
# Epoch: 0085 train cost=2.270541198 test cost=2.269472645
# Epoch: 0086 train cost=2.269993820 test cost=2.268900779
# Epoch: 0087 train cost=2.269438528 test cost=2.268339914
# Epoch: 0088 train cost=2.268877673 test cost=2.267765911
# Epoch: 0089 train cost=2.268307866 test cost=2.267184824
# Epoch: 0090 train cost=2.267731835 test cost=2.266587436
# Epoch: 0091 train cost=2.267147981 test cost=2.265984981
# Epoch: 0092 train cost=2.266555378 test cost=2.265381098
# Epoch: 0093 train cost=2.265955834 test cost=2.264763596
# Epoch: 0094 train cost=2.265348358 test cost=2.264137203
# Epoch: 0095 train cost=2.264732162 test cost=2.263509328
# Epoch: 0096 train cost=2.264108045 test cost=2.262873700
# Epoch: 0097 train cost=2.263475292 test cost=2.262220856
# Epoch: 0098 train cost=2.262833993 test cost=2.261568221
# Epoch: 0099 train cost=2.262183753 test cost=2.260897731
# Epoch: 0100 train cost=2.261525156 test cost=2.260215246
# Accuracy: 0.3333

# %%
h1_w = w['h1'].flatten().reshape(-1,1)
h2_w = w['h2'].flatten().reshape(-1,1)
out_w = w['out'].flatten().reshape(-1,1)


fig = plt.figure()
plt.subplot(1, 3, 1)
plt.title("Weight matrix")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Weight matrix ")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Weight matrix ")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# #Model 2: input (784) - ReLu(512) - ReLu(128) - sigmoid(output 10)

# %%
# Create model
def multilayer_perceptron_relu(x, weights, biases):
    # Use tf.matmul instead of "*" because tf.matmul can change it's dimensions on the fly (broadcast)
    print( 'x:', x.get_shape(), 'W[h1]:', weights['h1'].get_shape(), 'b[h1]:', biases['b1'].get_shape())        
    
    # Hidden layer with ReLu activation
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1']) #(x*weights['h1']) + biases['b1']
    layer_1 = tf.nn.relu(layer_1)
    print( 'layer_1:', layer_1.get_shape(), 'W[h2]:', weights['h2'].get_shape(), 'b[h2]:', biases['b2'].get_shape())        
    
    # Hidden layer with ReLu activation
    layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2']) # (layer_1 * weights['h2']) + biases['b2'] 
    layer_2 = tf.nn.relu(layer_2)
    print( 'layer_2:', layer_2.get_shape(), 'W[out]:', weights['out'].get_shape(), 'b3:', biases['out'].get_shape())        
    
    # Output layer with Sigmoid activation
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out'] # (layer_2 * weights['out']) + biases['out']    
    out_layer = tf.nn.sigmoid(out_layer)
    print('out_layer:',out_layer.get_shape())

    return out_layer

# %%
# Since we are using Relu activations in hiden layers we will be using weights that are initalized as weights_relu
yrelu = multilayer_perceptron_relu(x, weights_relu, biases)

# https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits
cost_relu = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = yrelu, labels = y_))
# https://github.com/amitmac/Question-Answering/issues/2
# there are many optimizers available: https://www.tensorflow.org/versions/r1.2/api_guides/python/train#Optimizers 
optimizer_relu_adam = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost_relu)
optimizer_relu_sgdc = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost_relu)
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    
    fig,ax = plt.subplots(1,1)
    ax.set_xlabel('epoch') ; ax.set_ylabel('Soft Max Cross Entropy loss')
    xs, ytrs, ytes = [], [], []
    for epoch in range(training_epochs):
        train_avg_cost = 0.
        test_avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)

        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)

            # here we use AdamOptimizer
            _, c, w = sess.run([optimizer_relu_adam, cost_relu, weights_relu], feed_dict={x: batch_xs, y_: batch_ys})
            train_avg_cost += c / total_batch
            c = sess.run(cost_relu, feed_dict={x: mnist.test.images, y_: mnist.test.labels})
            test_avg_cost += c / total_batch

        xs.append(epoch)
        ytrs.append(train_avg_cost)
        ytes.append(test_avg_cost)
        plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.3, 1.8, step=0.04), "input-ReLu(512)-ReLu(128)-sigmoid(output)-AdamOptimizer")

        if epoch%display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "train cost={:.9f}".format(train_avg_cost), "test cost={:.9f}".format(test_avg_cost))

    # plot final results
    plt_dynamic(xs, ytrs, ytes, ax,np.arange(1.3, 1.8, step=0.04), "input-ReLu(512)-ReLu(128)-sigmoid(output)-AdamOptimizer")

    # we are calculating the final accuracy on the test data
    correct_prediction = tf.equal(tf.argmax(yrelu,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# x: (?, 784) W[h1]: (784, 512) b[h1]: (512,)
# layer_1: (?, 512) W[h2]: (512, 128) b[h2]: (128,)
# layer_2: (?, 128) W[out]: (128, 10) b3: (10,)
# out_layer: (?, 10)
# Epoch: 0001 train cost=1.558863960 test cost=1.553809897
# Epoch: 0002 train cost=1.500869568 test cost=1.501984452
# Epoch: 0003 train cost=1.488610380 test cost=1.492479212
# Epoch: 0004 train cost=1.482727066 test cost=1.489153654
# Epoch: 0005 train cost=1.478434366 test cost=1.486031231
# Epoch: 0006 train cost=1.475590462 test cost=1.484320518
# Epoch: 0007 train cost=1.473480541 test cost=1.482918699
# Epoch: 0008 train cost=1.472103152 test cost=1.482520484
# Epoch: 0009 train cost=1.470486153 test cost=1.481997091
# Epoch: 0010 train cost=1.469727064 test cost=1.481558785
# Epoch: 0011 train cost=1.468763274 test cost=1.480968859
# Epoch: 0012 train cost=1.468208797 test cost=1.481250223
# Epoch: 0013 train cost=1.468463499 test cost=1.480946891
# Epoch: 0014 train cost=1.467842502 test cost=1.480608781
# Epoch: 0015 train cost=1.467086066 test cost=1.480197428
# Epoch: 0016 train cost=1.466656428 test cost=1.480296041
# Epoch: 0017 train cost=1.465965633 test cost=1.480015448
# Epoch: 0018 train cost=1.465989232 test cost=1.479685502
# Epoch: 0019 train cost=1.466056588 test cost=1.480470149
# Epoch: 0020 train cost=1.465800858 test cost=1.480406627
# Epoch: 0021 train cost=1.465139879 test cost=1.479596285
# Epoch: 0022 train cost=1.465369952 test cost=1.479517240
# Epoch: 0023 train cost=1.465357349 test cost=1.479149662
# Epoch: 0024 train cost=1.465247758 test cost=1.478957816
# Epoch: 0025 train cost=1.465198136 test cost=1.479512174
# Epoch: 0026 train cost=1.464558409 test cost=1.479033244
# Epoch: 0027 train cost=1.464449206 test cost=1.479749947
# Epoch: 0028 train cost=1.464598196 test cost=1.479335078
# Epoch: 0029 train cost=1.464560271 test cost=1.478832364
# Epoch: 0030 train cost=1.464906664 test cost=1.479765068
# Epoch: 0031 train cost=1.464397625 test cost=1.478966192
# Epoch: 0032 train cost=1.464484556 test cost=1.479443267
# Epoch: 0033 train cost=1.464194885 test cost=1.478376426
# Epoch: 0034 train cost=1.463769236 test cost=1.478565987
# Epoch: 0035 train cost=1.463827819 test cost=1.479032257
# Epoch: 0036 train cost=1.464321488 test cost=1.479465319
# Epoch: 0037 train cost=1.464392973 test cost=1.478818833
# Epoch: 0038 train cost=1.464101514 test cost=1.479069341
# Epoch: 0039 train cost=1.464351427 test cost=1.479261617
# Epoch: 0040 train cost=1.463434665 test cost=1.478782720
# Epoch: 0041 train cost=1.464059338 test cost=1.478533023
# Epoch: 0042 train cost=1.464080035 test cost=1.478328096
# Epoch: 0043 train cost=1.463975060 test cost=1.478034090
# Epoch: 0044 train cost=1.463707302 test cost=1.478643742
# Epoch: 0045 train cost=1.463918767 test cost=1.478996321
# Epoch: 0046 train cost=1.464037966 test cost=1.479502049
# Epoch: 0047 train cost=1.463564400 test cost=1.478774913
# Epoch: 0048 train cost=1.463892798 test cost=1.479036026
# Epoch: 0049 train cost=1.463975043 test cost=1.478849379
# Epoch: 0050 train cost=1.463627027 test cost=1.478102100
# Epoch: 0051 train cost=1.463829713 test cost=1.478803757
# Epoch: 0052 train cost=1.463960039 test cost=1.479185219
# Epoch: 0053 train cost=1.463917185 test cost=1.478309902
# Epoch: 0054 train cost=1.463755745 test cost=1.478627446
# Epoch: 0055 train cost=1.463989246 test cost=1.478895878
# Epoch: 0056 train cost=1.463441450 test cost=1.478186780
# Epoch: 0057 train cost=1.463480893 test cost=1.478294485
# Epoch: 0058 train cost=1.463425806 test cost=1.478487250
# Epoch: 0059 train cost=1.463650924 test cost=1.477561233
# Epoch: 0060 train cost=1.463438427 test cost=1.478694949
# Epoch: 0061 train cost=1.463538481 test cost=1.478432217
# Epoch: 0062 train cost=1.463763734 test cost=1.478327941
# Epoch: 0063 train cost=1.463436301 test cost=1.477445348
# Epoch: 0064 train cost=1.463418414 test cost=1.477949221
# Epoch: 0065 train cost=1.463492493 test cost=1.477386128
# Epoch: 0066 train cost=1.463452673 test cost=1.477535840
# Epoch: 0067 train cost=1.463452720 test cost=1.477597484
# Epoch: 0068 train cost=1.463264907 test cost=1.477486010
# Epoch: 0069 train cost=1.463683417 test cost=1.478171059
# Epoch: 0070 train cost=1.463707072 test cost=1.478055995
# Epoch: 0071 train cost=1.463676369 test cost=1.477555312
# Epoch: 0072 train cost=1.463745266 test cost=1.477359731
# Epoch: 0073 train cost=1.463477546 test cost=1.478063452
# Epoch: 0074 train cost=1.463263168 test cost=1.477570219
# Epoch: 0075 train cost=1.463014812 test cost=1.476893024
# Epoch: 0076 train cost=1.464126511 test cost=1.478066534
# Epoch: 0077 train cost=1.463602071 test cost=1.477420642
# Epoch: 0078 train cost=1.463259823 test cost=1.477705346
# Epoch: 0079 train cost=1.463384225 test cost=1.477744463
# Epoch: 0080 train cost=1.463387481 test cost=1.478071987
# Epoch: 0081 train cost=1.463595021 test cost=1.478020390
# Epoch: 0082 train cost=1.463454898 test cost=1.477327898
# Epoch: 0083 train cost=1.463283242 test cost=1.477973552
# Epoch: 0084 train cost=1.463196347 test cost=1.477012328
# Epoch: 0085 train cost=1.462736135 test cost=1.477902700
# Epoch: 0086 train cost=1.463323203 test cost=1.477934962
# Epoch: 0087 train cost=1.463846704 test cost=1.478496767
# Epoch: 0088 train cost=1.463812223 test cost=1.478132971
# Epoch: 0089 train cost=1.463478042 test cost=1.477640873
# Epoch: 0090 train cost=1.463622350 test cost=1.477558313
# Epoch: 0091 train cost=1.463577070 test cost=1.477025384
# Epoch: 0092 train cost=1.463296953 test cost=1.477881937
# Epoch: 0093 train cost=1.463218552 test cost=1.477153061
# Epoch: 0094 train cost=1.462860535 test cost=1.477478754
# Epoch: 0095 train cost=1.463111204 test cost=1.478222600
# Epoch: 0096 train cost=1.463345155 test cost=1.478163169
# Epoch: 0097 train cost=1.464227972 test cost=1.478730225
# Epoch: 0098 train cost=1.463464970 test cost=1.478189470
# Epoch: 0099 train cost=1.463691602 test cost=1.477813894
# Epoch: 0100 train cost=1.463370332 test cost=1.476827080
# Accuracy: 0.9832

# %%
h1_w = w['h1'].flatten().reshape(-1,1)
h2_w = w['h2'].flatten().reshape(-1,1)
out_w = w['out'].flatten().reshape(-1,1)


fig = plt.figure()
plt.subplot(1, 3, 1)
plt.title("Weight matrix")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Weight matrix ")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Weight matrix ")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# **ReLu(512)-ReLu(128)-sigmoid(output) - GradientDescentOptimizer**

# %%
# We can now launch the model in an InteractiveSession

# We first have to create an operation to initialize the variables we created:


# Make sure to initialize variables after AdamOptimizer

with tf.Session() as sess:
    tf.global_variables_initializer().run()
    fig,ax = plt.subplots(1,1)
    ax.set_xlabel('epoch') ; ax.set_ylabel('Soft Max Cross Entropy loss')
    xs, ytrs, ytes = [], [], []
    for epoch in range(training_epochs):
        train_avg_cost = 0.
        test_avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)

        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)

            # here we use GradientDescentOptimizer
            _, c, w = sess.run([optimizer_relu_sgdc, cost_relu, weights_relu], feed_dict={x: batch_xs, y_: batch_ys})
            train_avg_cost += c / total_batch
            c = sess.run(cost_relu, feed_dict={x: mnist.test.images, y_: mnist.test.labels})
            test_avg_cost += c / total_batch

        xs.append(epoch)
        ytrs.append(train_avg_cost)
        ytes.append(test_avg_cost)
        plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.5, 2.4, step=0.05), "input-ReLu(512)-ReLu(128)-sigmoid(output)-GradientDescentOptimizer")

        if epoch%display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "train cost={:.9f}".format(train_avg_cost), "test cost={:.9f}".format(test_avg_cost))

    # plot final results
    plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.5, 2.4, step=0.05), "input-ReLu(512)-ReLu(128)-sigmoid(output)-GradientDescentOptimizer")

    # we are calculating the final accuracy on the test data
    correct_prediction = tf.equal(tf.argmax(yrelu,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# Epoch: 0001 train cost=2.321509665 test cost=2.316798456
# Epoch: 0002 train cost=2.227539322 test cost=2.219945126
# Epoch: 0003 train cost=2.144788755 test cost=2.135815686
# Epoch: 0004 train cost=2.067583695 test cost=2.058638025
# Epoch: 0005 train cost=1.989005513 test cost=1.979689266
# Epoch: 0006 train cost=1.934081882 test cost=1.924469748
# Epoch: 0007 train cost=1.895377707 test cost=1.885935935
# Epoch: 0008 train cost=1.866585492 test cost=1.857340544
# Epoch: 0009 train cost=1.844205585 test cost=1.835351400
# Epoch: 0010 train cost=1.826191737 test cost=1.817553650
# Epoch: 0011 train cost=1.811140100 test cost=1.802762371
# Epoch: 0012 train cost=1.797553562 test cost=1.789487024
# Epoch: 0013 train cost=1.781139457 test cost=1.773214935
# Epoch: 0014 train cost=1.765221260 test cost=1.757221149
# Epoch: 0015 train cost=1.753694408 test cost=1.745608294
# Epoch: 0016 train cost=1.743808135 test cost=1.735641602
# Epoch: 0017 train cost=1.735142255 test cost=1.726996134
# Epoch: 0018 train cost=1.727488239 test cost=1.719296534
# Epoch: 0019 train cost=1.720611890 test cost=1.712434181
# Epoch: 0020 train cost=1.714382583 test cost=1.706266644
# Epoch: 0021 train cost=1.708686155 test cost=1.700572264
# Epoch: 0022 train cost=1.703432715 test cost=1.695370186
# Epoch: 0023 train cost=1.698567147 test cost=1.690548376
# Epoch: 0024 train cost=1.694039845 test cost=1.686053524
# Epoch: 0025 train cost=1.689789891 test cost=1.681857559
# Epoch: 0026 train cost=1.685807971 test cost=1.677937715
# Epoch: 0027 train cost=1.682051042 test cost=1.674233088
# Epoch: 0028 train cost=1.678499075 test cost=1.670756419
# Epoch: 0029 train cost=1.675144906 test cost=1.667479436
# Epoch: 0030 train cost=1.671954563 test cost=1.664333004
# Epoch: 0031 train cost=1.668943664 test cost=1.661376875
# Epoch: 0032 train cost=1.666065937 test cost=1.658529018
# Epoch: 0033 train cost=1.663321029 test cost=1.655828080
# Epoch: 0034 train cost=1.660692391 test cost=1.653257967
# Epoch: 0035 train cost=1.658191235 test cost=1.650779156
# Epoch: 0036 train cost=1.655786594 test cost=1.648438390
# Epoch: 0037 train cost=1.653489083 test cost=1.646150701
# Epoch: 0038 train cost=1.651288229 test cost=1.643990705
# Epoch: 0039 train cost=1.649164474 test cost=1.641890808
# Epoch: 0040 train cost=1.647131652 test cost=1.639895172
# Epoch: 0041 train cost=1.645162777 test cost=1.637965748
# Epoch: 0042 train cost=1.643275636 test cost=1.636122550
# Epoch: 0043 train cost=1.641451280 test cost=1.634297085
# Epoch: 0044 train cost=1.639690609 test cost=1.632590287
# Epoch: 0045 train cost=1.637981496 test cost=1.630902398
# Epoch: 0046 train cost=1.636348970 test cost=1.629294222
# Epoch: 0047 train cost=1.634753797 test cost=1.627740584
# Epoch: 0048 train cost=1.633223719 test cost=1.626215783
# Epoch: 0049 train cost=1.631729781 test cost=1.624750015
# Epoch: 0050 train cost=1.630292597 test cost=1.623368808
# Accuracy: 0.8805

# %%
h1_w = w['h1'].flatten().reshape(-1,1)
h2_w = w['h2'].flatten().reshape(-1,1)
out_w = w['out'].flatten().reshape(-1,1)


fig = plt.figure()
plt.subplot(1, 3, 1)
plt.title("Weight matrix")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Weight matrix ")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Weight matrix ")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# **Model 3: Input - Sigmoid(BatchNormalization(512)) - Sigmoid(BatchNormalization(128))- Sigmoid(output)**

# %%
# https://www.tensorflow.org/api_docs/python/tf/nn/batch_normalization
# https://r2rt.com/implementing-batch-normalization-in-tensorflow.html
epsilon = 1e-3
def multilayer_perceptron_batch(x, weights, biases):
    # Use tf.matmul instead of "*" because tf.matmul can change it's dimensions on the fly (broadcast)
    print( 'x:', x.get_shape(), 'W[h1]:', weights['h1'].get_shape(), 'b[h1]:', biases['b1'].get_shape())        
    
    ############################################################
    # Hidden layer with Sigmoid activation and batch normalization
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1']) #(x*weights['h1']) + biases['b1']
    
    # https://www.tensorflow.org/api_docs/python/tf/nn/moments
    # Calculate the mean and variance of x.
    batch_mean_1, batch_var_1 = tf.nn.moments(layer_1,[0])
    
    scale_1 = tf.Variable(tf.ones([n_hidden_1]))
    beta_1 = tf.Variable(tf.zeros([n_hidden_1]))
    
    # https://www.tensorflow.org/api_docs/python/tf/nn/batch_normalization
    layer_1 = tf.nn.batch_normalization(layer_1, batch_mean_1, batch_var_1, beta_1, scale_1, epsilon)
    layer_1 = tf.nn.sigmoid(layer_1)
    
    print( 'layer_1:', layer_1.get_shape(), 'W[h2]:', weights['h2'].get_shape(), 'b[h2]:', biases['b2'].get_shape())        
    
    #####################################################################################
    
    # Hidden layer with Sigmoid activation and batch normalization
    layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2']) # (layer_1 * weights['h2']) + biases['b2'] 
    
    # https://www.tensorflow.org/api_docs/python/tf/nn/moments
    # Calculate the mean and variance of x.
    batch_mean_2, batch_var_2 = tf.nn.moments(layer_2, [0])
    
    scale_2 = tf.Variable(tf.ones([n_hidden_2]))
    beta_2 = tf.Variable(tf.zeros([n_hidden_2]))
    
    layer_2 = tf.nn.batch_normalization(layer_2, batch_mean_2, batch_var_2, beta_2, scale_2, epsilon)
    layer_2 = tf.nn.sigmoid(layer_2)
    print( 'layer_2:', layer_2.get_shape(), 'W[out]:', weights['out'].get_shape(), 'b3:', biases['out'].get_shape())        
    
    ######################################################################################
    
    # output layer with Sigmoid activation 
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out'] # (layer_2 * weights['out']) + biases['out']    
    out_layer = tf.nn.sigmoid(out_layer)
    print('out_layer:',out_layer.get_shape())

    return out_layer

# %% [markdown]
# **Model 3 with Adam Optimizer**

# %%
# Since we are using sigmoid activations in hiden layers we will be using weights that are initalized as weights_sgd
ybatch = multilayer_perceptron_batch(x, weights_sgd, biases)

# https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits
cost_batch = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = ybatch, labels = y_))
# https://github.com/amitmac/Question-Answering/issues/2
# there are many optimizers available: https://www.tensorflow.org/versions/r1.2/api_guides/python/train#Optimizers 
optimizer_batch_adam = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost_batch)
optimizer_batch_sgdc = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost_batch)
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    fig,ax = plt.subplots(1,1)
    ax.set_xlabel('epoch') ; ax.set_ylabel('Soft Max Cross Entropy loss')
    xs, ytrs, ytes = [], [], []
    for epoch in range(training_epochs):
        train_avg_cost = 0.
        test_avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)

        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)

            # here we use AdamOptimizer
            _, c, w = sess.run([optimizer_batch_adam, cost_batch, weights_sgd], feed_dict={x: batch_xs, y_: batch_ys})
            train_avg_cost += c / total_batch
            c = sess.run(cost_batch, feed_dict={x: mnist.test.images, y_: mnist.test.labels})
            test_avg_cost += c / total_batch

        xs.append(epoch)
        ytrs.append(train_avg_cost)
        ytes.append(test_avg_cost)
        plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.3, 1.8, step=0.04), "input-Sigmoid(BN(512))-Sigmoid(BN(128))-Sigmoid(output)-AdamOptimizer")

        if epoch%display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "train cost={:.9f}".format(train_avg_cost), "test cost={:.9f}".format(test_avg_cost))

    # plot final results
    plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.3, 1.8, step=0.04), "input-Sigmoid(BN(512))-Sigmoid(BN(128))-Sigmoid(output)-AdamOptimizer")

    # we are calculating the final accuracy on the test data
    correct_prediction = tf.equal(tf.argmax(ybatch,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# x: (?, 784) W[h1]: (784, 512) b[h1]: (512,)
# layer_1: (?, 512) W[h2]: (512, 128) b[h2]: (128,)
# layer_2: (?, 128) W[out]: (128, 10) b3: (10,)
# out_layer: (?, 10)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch: 0001 train cost=1.697667968 test cost=1.689333970
# Epoch: 0002 train cost=1.554137292 test cost=1.550786987
# Epoch: 0003 train cost=1.516122974 test cost=1.515506031
# Epoch: 0004 train cost=1.500450389 test cost=1.501982761
# Epoch: 0005 train cost=1.491390617 test cost=1.494789489
# Epoch: 0006 train cost=1.486090121 test cost=1.491460966
# Epoch: 0007 train cost=1.482240193 test cost=1.488212924
# Epoch: 0008 train cost=1.478775082 test cost=1.486447946
# Epoch: 0009 train cost=1.477364177 test cost=1.485353771
# Epoch: 0010 train cost=1.475260521 test cost=1.484205269
# Epoch: 0011 train cost=1.473408004 test cost=1.483065278
# Epoch: 0012 train cost=1.472226460 test cost=1.482310045
# Epoch: 0013 train cost=1.471575944 test cost=1.482188640
# Epoch: 0014 train cost=1.470511063 test cost=1.481614506
# Epoch: 0015 train cost=1.469464036 test cost=1.481465636
# Epoch: 0016 train cost=1.469192652 test cost=1.481757392
# Epoch: 0017 train cost=1.469047668 test cost=1.480887899
# Epoch: 0018 train cost=1.467809549 test cost=1.480477857
# Epoch: 0019 train cost=1.467257042 test cost=1.480175611
# Epoch: 0020 train cost=1.467121260 test cost=1.480760045
# Epoch: 0021 train cost=1.467227978 test cost=1.480665346
# Epoch: 0022 train cost=1.466466006 test cost=1.480212677
# Epoch: 0023 train cost=1.466440056 test cost=1.480405730
# Epoch: 0024 train cost=1.465850416 test cost=1.479988253
# Epoch: 0025 train cost=1.465778477 test cost=1.479545294
# Epoch: 0026 train cost=1.465343836 test cost=1.480624137
# Epoch: 0027 train cost=1.465845668 test cost=1.480385397
# Epoch: 0028 train cost=1.465137188 test cost=1.479238033
# Epoch: 0029 train cost=1.464551811 test cost=1.479325228
# Epoch: 0030 train cost=1.465120443 test cost=1.479478983
# Epoch: 0031 train cost=1.464934185 test cost=1.479849409
# Epoch: 0032 train cost=1.464759494 test cost=1.478756195
# Epoch: 0033 train cost=1.464443506 test cost=1.479164549
# Epoch: 0034 train cost=1.464591265 test cost=1.479352745
# Epoch: 0035 train cost=1.464246520 test cost=1.478956791
# Epoch: 0036 train cost=1.463762583 test cost=1.478841414
# Epoch: 0037 train cost=1.464256600 test cost=1.479189302
# Epoch: 0038 train cost=1.464199858 test cost=1.479491770
# Epoch: 0039 train cost=1.463315068 test cost=1.478288112
# Epoch: 0040 train cost=1.463873339 test cost=1.479257436
# Epoch: 0041 train cost=1.463856849 test cost=1.479242996
# Epoch: 0042 train cost=1.463845836 test cost=1.478036420
# Epoch: 0043 train cost=1.463490822 test cost=1.479017681
# Epoch: 0044 train cost=1.463730200 test cost=1.479598890
# Epoch: 0045 train cost=1.463697612 test cost=1.478522304
# Epoch: 0046 train cost=1.463300974 test cost=1.478413649
# Epoch: 0047 train cost=1.463173054 test cost=1.478721926
# Epoch: 0048 train cost=1.463213968 test cost=1.479363461
# Epoch: 0049 train cost=1.463184417 test cost=1.479937710
# Epoch: 0050 train cost=1.463162822 test cost=1.478861100
# Accuracy: 0.9818

# %%
h1_w = w['h1'].flatten().reshape(-1,1)
h2_w = w['h2'].flatten().reshape(-1,1)
out_w = w['out'].flatten().reshape(-1,1)


fig = plt.figure()
plt.subplot(1, 3, 1)
plt.title("Weight matrix")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Weight matrix ")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Weight matrix ")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# Model 3 with Gradient Descent Optimizer

# %%
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    fig,ax = plt.subplots(1,1)
    ax.set_xlabel('epoch') ; ax.set_ylabel('Soft Max Cross Entropy loss')
    xs, ytrs, ytes = [], [], []
    for epoch in range(training_epochs):
        train_avg_cost = 0.
        test_avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)

        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)

            # here we use GradientDescentOptimizer
            _, c, w = sess.run([optimizer_batch_sgdc, cost_batch, weights_sgd], feed_dict={x: batch_xs, y_: batch_ys})
            train_avg_cost += c / total_batch
            c = sess.run(cost_batch, feed_dict={x: mnist.test.images, y_: mnist.test.labels})
            test_avg_cost += c / total_batch

        xs.append(epoch)
        ytrs.append(train_avg_cost)
        ytes.append(test_avg_cost)
        plt_dynamic(xs, ytrs, ytes, ax,np.arange(1.5, 2.4, step=0.05), "input-Sigmoid(BN(512))-Sigmoid(BN(128))-Sigmoid(output)-GradientDescentOptimizer")

        if epoch%display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "train cost={:.9f}".format(train_avg_cost), "test cost={:.9f}".format(test_avg_cost))

    # plot final results
    plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.5, 2.4, step=0.05), "input-Sigmoid(BN(512))-Sigmoid(BN(128))-Sigmoid(output)-GradientDescentOptimizer")

    # we are calculating the final accuracy on the test data
    correct_prediction = tf.equal(tf.argmax(ybatch,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# Epoch: 0001 train cost=2.319629274 test cost=2.320529026
# Epoch: 0002 train cost=2.282610404 test cost=2.282330591
# Epoch: 0003 train cost=2.245107988 test cost=2.243535444
# Epoch: 0004 train cost=2.210171726 test cost=2.207523905
# Epoch: 0005 train cost=2.179199741 test cost=2.175606041
# Epoch: 0006 train cost=2.151590070 test cost=2.147420353
# Epoch: 0007 train cost=2.126844169 test cost=2.122033668
# Epoch: 0008 train cost=2.103964632 test cost=2.098933902
# Epoch: 0009 train cost=2.083487102 test cost=2.077934836
# Epoch: 0010 train cost=2.064841035 test cost=2.059234300
# Epoch: 0011 train cost=2.048718361 test cost=2.042765579
# Epoch: 0012 train cost=2.034457644 test cost=2.028455564
# Epoch: 0013 train cost=2.021926317 test cost=2.015886191
# Epoch: 0014 train cost=2.011060684 test cost=2.004742313
# Epoch: 0015 train cost=2.001073343 test cost=1.994707897
# Epoch: 0016 train cost=1.991944520 test cost=1.985514876
# Epoch: 0017 train cost=1.983510187 test cost=1.977063076
# Epoch: 0018 train cost=1.975801662 test cost=1.969175371
# Epoch: 0019 train cost=1.968412796 test cost=1.961801313
# Epoch: 0020 train cost=1.961569960 test cost=1.954860931
# Epoch: 0021 train cost=1.955118692 test cost=1.948297310
# Epoch: 0022 train cost=1.948766382 test cost=1.942062471
# Epoch: 0023 train cost=1.943004513 test cost=1.936123811
# Epoch: 0024 train cost=1.937135019 test cost=1.930460730
# Epoch: 0025 train cost=1.931803759 test cost=1.925039675
# Epoch: 0026 train cost=1.926716897 test cost=1.919830642
# Epoch: 0027 train cost=1.921655077 test cost=1.914828273
# Epoch: 0028 train cost=1.916846879 test cost=1.910010074
# Epoch: 0029 train cost=1.912354942 test cost=1.905377103
# Epoch: 0030 train cost=1.907873706 test cost=1.900894375
# Epoch: 0031 train cost=1.903676726 test cost=1.896562770
# Epoch: 0032 train cost=1.899277368 test cost=1.892373703
# Epoch: 0033 train cost=1.895417205 test cost=1.888319492
# Epoch: 0034 train cost=1.891568624 test cost=1.884386451
# Epoch: 0035 train cost=1.887803721 test cost=1.880562633
# Epoch: 0036 train cost=1.884060612 test cost=1.876853767
# Epoch: 0037 train cost=1.880632850 test cost=1.873247737
# Epoch: 0038 train cost=1.877162131 test cost=1.869743565
# Epoch: 0039 train cost=1.873571822 test cost=1.866331872
# Epoch: 0040 train cost=1.870173396 test cost=1.863002553
# Epoch: 0041 train cost=1.866803035 test cost=1.859759355
# Epoch: 0042 train cost=1.864134469 test cost=1.856599236
# Epoch: 0043 train cost=1.860774375 test cost=1.853520434
# Epoch: 0044 train cost=1.857890987 test cost=1.850507747
# Epoch: 0045 train cost=1.854895186 test cost=1.847571274
# Epoch: 0046 train cost=1.852226187 test cost=1.844698453
# Epoch: 0047 train cost=1.849296962 test cost=1.841887659
# Epoch: 0048 train cost=1.846570807 test cost=1.839146834
# Epoch: 0049 train cost=1.843970397 test cost=1.836457910
# Epoch: 0050 train cost=1.841330594 test cost=1.833834145
# Accuracy: 0.8631

# %%
h1_w = w['h1'].flatten().reshape(-1,1)
h2_w = w['h2'].flatten().reshape(-1,1)
out_w = w['out'].flatten().reshape(-1,1)


fig = plt.figure()
plt.subplot(1, 3, 1)
plt.title("Weight matrix")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Weight matrix ")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Weight matrix ")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# **Model 4: Input - Relu(BatchNormalization(512)) - Relu(BatchNormalization(128))- Sigmoid(output)**

# %%
# https://www.tensorflow.org/api_docs/python/tf/nn/batch_normalization
# https://r2rt.com/implementing-batch-normalization-in-tensorflow.html
epsilon = 1e-3
def multilayer_perceptron_batch(x, weights, biases):
    # Use tf.matmul instead of "*" because tf.matmul can change it's dimensions on the fly (broadcast)
    print( 'x:', x.get_shape(), 'W[h1]:', weights['h1'].get_shape(), 'b[h1]:', biases['b1'].get_shape())        
    
    ############################################################
    # Hidden layer with Sigmoid activation and batch normalization
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1']) #(x*weights['h1']) + biases['b1']
    
    # https://www.tensorflow.org/api_docs/python/tf/nn/moments
    # Calculate the mean and variance of x.
    batch_mean_1, batch_var_1 = tf.nn.moments(layer_1,[0])
    
    scale_1 = tf.Variable(tf.ones([n_hidden_1]))
    beta_1 = tf.Variable(tf.zeros([n_hidden_1]))
    
    # https://www.tensorflow.org/api_docs/python/tf/nn/batch_normalization
    layer_1 = tf.nn.batch_normalization(layer_1, batch_mean_1, batch_var_1, beta_1, scale_1, epsilon)
    layer_1 = tf.nn.relu(layer_1)
    
    print( 'layer_1:', layer_1.get_shape(), 'W[h2]:', weights['h2'].get_shape(), 'b[h2]:', biases['b2'].get_shape())        
    
    #####################################################################################
    
    # Hidden layer with Sigmoid activation and batch normalization
    layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2']) # (layer_1 * weights['h2']) + biases['b2'] 
    
    # https://www.tensorflow.org/api_docs/python/tf/nn/moments
    # Calculate the mean and variance of x.
    batch_mean_2, batch_var_2 = tf.nn.moments(layer_2, [0])
    
    scale_2 = tf.Variable(tf.ones([n_hidden_2]))
    beta_2 = tf.Variable(tf.zeros([n_hidden_2]))
    
    layer_2 = tf.nn.batch_normalization(layer_2, batch_mean_2, batch_var_2, beta_2, scale_2, epsilon)
    layer_2 = tf.nn.relu(layer_2)
    print( 'layer_2:', layer_2.get_shape(), 'W[out]:', weights['out'].get_shape(), 'b3:', biases['out'].get_shape())        
    
    ######################################################################################
    
    # output layer with Sigmoid activation 
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out'] # (layer_2 * weights['out']) + biases['out']    
    out_layer = tf.nn.sigmoid(out_layer)
    print('out_layer:',out_layer.get_shape())

    return out_layer

# %% [markdown]
# Model 4 with Adam Optimizer

# %%
# Since we are using sigmoid activations in hiden layers we will be using weights that are initalized as weights_sgd
ybatch = multilayer_perceptron_batch(x, weights_sgd, biases)

# https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits
cost_batch = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = ybatch, labels = y_))
# https://github.com/amitmac/Question-Answering/issues/2
# there are many optimizers available: https://www.tensorflow.org/versions/r1.2/api_guides/python/train#Optimizers 
optimizer_batch_adam = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost_batch)
optimizer_batch_sgdc = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost_batch)
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    fig,ax = plt.subplots(1,1)
    ax.set_xlabel('epoch') ; ax.set_ylabel('Soft Max Cross Entropy loss')
    xs, ytrs, ytes = [], [], []
    for epoch in range(training_epochs):
        train_avg_cost = 0.
        test_avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)

        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)

            # here we use AdamOptimizer
            _, c, w = sess.run([optimizer_batch_adam, cost_batch, weights_sgd], feed_dict={x: batch_xs, y_: batch_ys})
            train_avg_cost += c / total_batch
            c = sess.run(cost_batch, feed_dict={x: mnist.test.images, y_: mnist.test.labels})
            test_avg_cost += c / total_batch

        xs.append(epoch)
        ytrs.append(train_avg_cost)
        ytes.append(test_avg_cost)
        plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.3, 1.8, step=0.04), "input-Sigmoid(BN(512))-Sigmoid(BN(128))-Sigmoid(output)-AdamOptimizer")

        if epoch%display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "train cost={:.9f}".format(train_avg_cost), "test cost={:.9f}".format(test_avg_cost))

    # plot final results
    plt_dynamic(xs, ytrs, ytes, ax, np.arange(1.3, 1.8, step=0.04), "input-Sigmoid(BN(512))-Sigmoid(BN(128))-Sigmoid(output)-AdamOptimizer")

    # we are calculating the final accuracy on the test data
    correct_prediction = tf.equal(tf.argmax(ybatch,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# x: (?, 784) W[h1]: (784, 512) b[h1]: (512,)
# layer_1: (?, 512) W[h2]: (512, 128) b[h2]: (128,)
# layer_2: (?, 128) W[out]: (128, 10) b3: (10,)
# out_layer: (?, 10)
# Epoch: 0001 train cost=1.550719215 test cost=1.542217735
# Epoch: 0002 train cost=1.489568850 test cost=1.489876929
# Epoch: 0003 train cost=1.480976825 test cost=1.484142343
# Epoch: 0004 train cost=1.476471038 test cost=1.481534824
# Epoch: 0005 train cost=1.473359068 test cost=1.480400524
# Epoch: 0006 train cost=1.471591799 test cost=1.479522575
# Epoch: 0007 train cost=1.469827126 test cost=1.479425985
# Epoch: 0008 train cost=1.469395839 test cost=1.479432216
# Epoch: 0009 train cost=1.468494422 test cost=1.479062848
# Epoch: 0010 train cost=1.467538627 test cost=1.478531547
# Epoch: 0011 train cost=1.466986813 test cost=1.478505831
# Epoch: 0012 train cost=1.466439990 test cost=1.479148156
# Epoch: 0013 train cost=1.466226330 test cost=1.477945618
# Epoch: 0014 train cost=1.465848802 test cost=1.477917459
# Epoch: 0015 train cost=1.465735627 test cost=1.478504992
# Epoch: 0016 train cost=1.465073020 test cost=1.477868209
# Epoch: 0017 train cost=1.465052503 test cost=1.477412100
# Epoch: 0018 train cost=1.465070023 test cost=1.477995825
# Epoch: 0019 train cost=1.464737362 test cost=1.478032060
# Epoch: 0020 train cost=1.464288969 test cost=1.478059185
# Epoch: 0021 train cost=1.463902120 test cost=1.477882981
# Epoch: 0022 train cost=1.464500880 test cost=1.478306215
# Epoch: 0023 train cost=1.464070721 test cost=1.477606898
# Epoch: 0024 train cost=1.464390268 test cost=1.477500795
# Epoch: 0025 train cost=1.463789753 test cost=1.477504001
# Epoch: 0026 train cost=1.463788573 test cost=1.478262251
# Epoch: 0027 train cost=1.463544395 test cost=1.477340020
# Epoch: 0028 train cost=1.463941031 test cost=1.477783266
# Epoch: 0029 train cost=1.463889853 test cost=1.476743308
# Epoch: 0030 train cost=1.463449466 test cost=1.477141414
# Epoch: 0031 train cost=1.463613001 test cost=1.477607680
# Epoch: 0032 train cost=1.463216690 test cost=1.476648356
# Epoch: 0033 train cost=1.463206648 test cost=1.477098664
# Epoch: 0034 train cost=1.463110372 test cost=1.476896873
# Epoch: 0035 train cost=1.463508640 test cost=1.476922985
# Epoch: 0036 train cost=1.463451289 test cost=1.476774476
# Epoch: 0037 train cost=1.463264476 test cost=1.476577496
# Epoch: 0038 train cost=1.462875386 test cost=1.476270608
# Epoch: 0039 train cost=1.462872515 test cost=1.476748429
# Epoch: 0040 train cost=1.462956288 test cost=1.477083756
# Epoch: 0041 train cost=1.462985125 test cost=1.477537392
# Epoch: 0042 train cost=1.463028488 test cost=1.476642130
# Epoch: 0043 train cost=1.463218859 test cost=1.477335504
# Epoch: 0044 train cost=1.462874053 test cost=1.476949040
# Epoch: 0045 train cost=1.462870104 test cost=1.476706145
# Epoch: 0046 train cost=1.462765962 test cost=1.476642284
# Epoch: 0047 train cost=1.462704455 test cost=1.477265700
# Epoch: 0048 train cost=1.462653864 test cost=1.476547741
# Epoch: 0049 train cost=1.462506905 test cost=1.476667259
# Epoch: 0050 train cost=1.462426449 test cost=1.477040184
# Accuracy: 0.9824

# %%
h1_w = w['h1'].flatten().reshape(-1,1)
h2_w = w['h2'].flatten().reshape(-1,1)
out_w = w['out'].flatten().reshape(-1,1)


fig = plt.figure()
plt.subplot(1, 3, 1)
plt.title("Weight matrix")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Weight matrix ")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Weight matrix ")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# Model 5: Input - ReLu(512) - Dropout - ReLu(128)- Dropout -Sigmoid(output)

# %%
# Create model
def multilayer_perceptron_dropout(x, weights, biases):
    # Use tf.matmul instead of "*" because tf.matmul can change it's dimensions on the fly (broadcast)
    print( 'x:', x.get_shape(), 'W[h1]:', weights['h1'].get_shape(), 'b[h1]:', biases['b1'].get_shape())        
    
    # we are adding a drop out layer after input layers with parameter keep_prob_input
    # Hidden layer with ReLu activation
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1']) #(x*weights['h1']) + biases['b1']
    layer_1 = tf.nn.relu(layer_1)
    # we are adding a drop out layer after the first hidden layer with parameter keep_prob
    layer_1_drop = tf.nn.dropout(layer_1, keep_prob)
    
    print( 'layer_1:', layer_1.get_shape(), 'W[h2]:', weights['h2'].get_shape(), 'b[h2]:', biases['b2'].get_shape())        
    
    # Hidden layer with ReLu activation
    layer_2 = tf.add(tf.matmul(layer_1_drop, weights['h2']), biases['b2']) # (layer_1 * weights['h2']) + biases['b2'] 
    layer_2 = tf.nn.relu(layer_2)
    
    # we are adding a drop out layer after the first hidden layer with parameter keep_prob
    layer_2_drop = tf.nn.dropout(layer_2, keep_prob)
    print( 'layer_2:', layer_2.get_shape(), 'W[out]:', weights['out'].get_shape(), 'b3:', biases['out'].get_shape())        
    
    # Output layer with Sigmoid activation
    out_layer = tf.matmul(layer_2_drop, weights['out']) + biases['out'] # (layer_2 * weights['out']) + biases['out']    
    out_layer = tf.nn.sigmoid(out_layer)
    print('out_layer:',out_layer.get_shape())

    return out_layer

# %% [markdown]
# Model 5 with Adam Optimizer

# %%
# Since we are using Relu activations in hiden layers we will be using weights that are initalized as weights_relu
ydrop = multilayer_perceptron_dropout(x, weights_relu, biases)

# https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits
cost_drop = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = ydrop, labels = y_))
# https://github.com/amitmac/Question-Answering/issues/2
# there are many optimizers available: https://www.tensorflow.org/versions/r1.2/api_guides/python/train#Optimizers 
optimizer_drop_adam = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost_drop)
optimizer_drop_sgdc = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost_drop)

with tf.Session() as sess:
    tf.global_variables_initializer().run()
    fig,ax = plt.subplots(1,1)
    ax.set_xlabel('epoch') ; ax.set_ylabel('Soft Max Cross Entropy loss')
    xs, ytrs, ytes = [], [], []
    for epoch in range(training_epochs):
        train_avg_cost = 0.
        test_avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)

        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            
            # here we use AdamOptimizer
            _, c, w = sess.run([optimizer_drop_adam, cost_drop, weights_relu], feed_dict={x: batch_xs, y_: batch_ys, keep_prob: 0.5})
            train_avg_cost += c / total_batch
            c = sess.run(cost_drop, feed_dict={x: mnist.test.images, y_: mnist.test.labels,  keep_prob: 1.0})
            test_avg_cost += c / total_batch

        xs.append(epoch)
        ytrs.append(train_avg_cost)
        ytes.append(test_avg_cost)
        plt_dynamic(xs, ytrs, ytes, ax,np.arange(1, 1.8, step=0.05), "input-ReLu(512)-Dropout-ReLu(128)-Dropout-Sigmoid(output)-AdamOptimizer")

        if epoch%display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "train cost={:.9f}".format(train_avg_cost), "test cost={:.9f}".format(test_avg_cost))

    # plot final results
    plt_dynamic(xs, ytrs, ytes, ax,np.arange(1, 1.8, step=0.05), "input-ReLu(512)-Dropout-ReLu(128)-Dropout-Sigmoid(output)-AdamOptimizer")

    # we are calculating the final accuracy on the test data
    correct_prediction = tf.equal(tf.argmax(ydrop,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0 }))
# Out:
# x: (?, 784) W[h1]: (784, 512) b[h1]: (512,)
# WARNING:tensorflow:From <ipython-input-48-5214f7a2eda2>:10: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# layer_1: (?, 512) W[h2]: (512, 128) b[h2]: (128,)
# layer_2: (?, 128) W[out]: (128, 10) b3: (10,)
# out_layer: (?, 10)
# Epoch: 0001 train cost=1.681832925 test cost=1.606635197
# Epoch: 0002 train cost=1.551047493 test cost=1.517656306
# Epoch: 0003 train cost=1.526984276 test cost=1.504301678
# Epoch: 0004 train cost=1.516647001 test cost=1.497379170
# Epoch: 0005 train cost=1.508817648 test cost=1.493293790
# Epoch: 0006 train cost=1.505042977 test cost=1.490217356
# Epoch: 0007 train cost=1.501550822 test cost=1.488461393
# Epoch: 0008 train cost=1.499076786 test cost=1.486802942
# Epoch: 0009 train cost=1.495452141 test cost=1.485375289
# Epoch: 0010 train cost=1.493345639 test cost=1.484503217
# Epoch: 0011 train cost=1.491519288 test cost=1.484214500
# Epoch: 0012 train cost=1.490384412 test cost=1.483649907
# Epoch: 0013 train cost=1.489159080 test cost=1.482995322
# Epoch: 0014 train cost=1.487652125 test cost=1.482813195
# Epoch: 0015 train cost=1.486633029 test cost=1.482033671
# Epoch: 0016 train cost=1.485923679 test cost=1.482227993
# Epoch: 0017 train cost=1.485342925 test cost=1.481754916
# Epoch: 0018 train cost=1.484734865 test cost=1.481461066
# Epoch: 0019 train cost=1.484194670 test cost=1.480634614
# Epoch: 0020 train cost=1.484140284 test cost=1.480624328
# Epoch: 0021 train cost=1.482856067 test cost=1.480347208
# Epoch: 0022 train cost=1.482969127 test cost=1.480200718
# Epoch: 0023 train cost=1.482042490 test cost=1.480244198
# Epoch: 0024 train cost=1.482244338 test cost=1.479340020
# Epoch: 0025 train cost=1.481157897 test cost=1.479613139
# Epoch: 0026 train cost=1.481073100 test cost=1.479996362
# Epoch: 0027 train cost=1.480574587 test cost=1.479978995
# Epoch: 0028 train cost=1.480466675 test cost=1.480051087
# Epoch: 0029 train cost=1.480719312 test cost=1.478966502
# Epoch: 0030 train cost=1.480820225 test cost=1.479554286
# Epoch: 0031 train cost=1.480312479 test cost=1.479232365
# Epoch: 0032 train cost=1.480032930 test cost=1.478901256
# Epoch: 0033 train cost=1.479830554 test cost=1.478768641
# Epoch: 0034 train cost=1.479530471 test cost=1.479310688
# Epoch: 0035 train cost=1.479219449 test cost=1.479274155
# Epoch: 0036 train cost=1.479710231 test cost=1.479170908
# Epoch: 0037 train cost=1.478987146 test cost=1.479316568
# Epoch: 0038 train cost=1.478956976 test cost=1.479022618
# Epoch: 0039 train cost=1.478688333 test cost=1.479144982
# Epoch: 0040 train cost=1.479036336 test cost=1.478652251
# Epoch: 0041 train cost=1.478400348 test cost=1.478876143
# Epoch: 0042 train cost=1.478042485 test cost=1.478665199
# Epoch: 0043 train cost=1.477481085 test cost=1.478196388
# Epoch: 0044 train cost=1.478215101 test cost=1.477784476
# Epoch: 0045 train cost=1.477765940 test cost=1.478228672
# Epoch: 0046 train cost=1.477335376 test cost=1.477820701
# Epoch: 0047 train cost=1.477252278 test cost=1.477749380
# Epoch: 0048 train cost=1.477474598 test cost=1.478463836
# Epoch: 0049 train cost=1.478009496 test cost=1.478034486
# Epoch: 0050 train cost=1.476928517 test cost=1.478232527
# Accuracy: 0.9791

# %%
h1_w = w['h1'].flatten().reshape(-1,1)
h2_w = w['h2'].flatten().reshape(-1,1)
out_w = w['out'].flatten().reshape(-1,1)


fig = plt.figure()
plt.subplot(1, 3, 1)
plt.title("Weight matrix")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Weight matrix ")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Weight matrix ")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
# plt.show()
# Out:
# Text(0.5, 0, 'Output Layer ')

# %% [markdown]
# Model 5 with Gradient Descent Optimizer

# %%
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    fig,ax = plt.subplots(1,1)
    ax.set_xlabel('epoch') ; ax.set_ylabel('Soft Max Cross Entropy loss')
    xs, ytrs, ytes = [], [], []
    for epoch in range(training_epochs):
        train_avg_cost = 0.
        test_avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)

        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            
            # here we use GradientDescentOptimizer
            _, c, w = sess.run([optimizer_drop_sgdc, cost_drop, weights_relu], feed_dict={x: batch_xs, y_: batch_ys, keep_prob: 0.5})
            train_avg_cost += c / total_batch
            c = sess.run(cost_drop, feed_dict={x: mnist.test.images, y_: mnist.test.labels,  keep_prob: 1.0})
            test_avg_cost += c / total_batch

        xs.append(epoch)
        ytrs.append(train_avg_cost)
        ytes.append(test_avg_cost)
        plt_dynamic(xs, ytrs, ytes, ax,np.arange(1, 1.8, step=0.05), "input-ReLu(512)-Dropout-ReLu(128)-Dropout-Sigmoid(output)-AdamOptimizer")

        if epoch%display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "train cost={:.9f}".format(train_avg_cost), "test cost={:.9f}".format(test_avg_cost))

    # plot final results
    plt_dynamic(xs, ytrs, ytes, ax,np.arange(1, 1.8, step=0.05), "input-ReLu(512)-Dropout-ReLu(128)-Dropout-Sigmoid(output)-AdamOptimizer")

    # we are calculating the final accuracy on the test data
    correct_prediction = tf.equal(tf.argmax(ydrop,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0 }))
# Out:
# Epoch: 0001 train cost=2.351351624 test cost=2.288414428
# Epoch: 0002 train cost=2.332448987 test cost=2.245839302
# Epoch: 0003 train cost=2.317554019 test cost=2.202834569
# Epoch: 0004 train cost=2.295161830 test cost=2.162967884
# Epoch: 0005 train cost=2.278270715 test cost=2.126778153
# Epoch: 0006 train cost=2.259247027 test cost=2.092971966
# Epoch: 0007 train cost=2.242815813 test cost=2.060136531
# Epoch: 0008 train cost=2.223841978 test cost=2.028235423
# Epoch: 0009 train cost=2.206814452 test cost=1.997872828
# Epoch: 0010 train cost=2.191098039 test cost=1.970249225
# Epoch: 0011 train cost=2.173336912 test cost=1.945720117
# Epoch: 0012 train cost=2.155574023 test cost=1.924572270
# Epoch: 0013 train cost=2.138279614 test cost=1.905943175
# Epoch: 0014 train cost=2.123277424 test cost=1.889735693
# Epoch: 0015 train cost=2.106722210 test cost=1.875608641
# Epoch: 0016 train cost=2.092734625 test cost=1.862984594
# Epoch: 0017 train cost=2.079439771 test cost=1.852312246
# Epoch: 0018 train cost=2.066472348 test cost=1.842061707
# Epoch: 0019 train cost=2.052204639 test cost=1.832294203
# Epoch: 0020 train cost=2.038426362 test cost=1.822336442
# Epoch: 0021 train cost=2.029107911 test cost=1.813771043
# Epoch: 0022 train cost=2.014874868 test cost=1.804989084
# Epoch: 0023 train cost=2.007154995 test cost=1.797453430
# Epoch: 0024 train cost=1.997620463 test cost=1.790536944
# Epoch: 0025 train cost=1.986385684 test cost=1.785255995
# Epoch: 0026 train cost=1.975645196 test cost=1.779596001
# Epoch: 0027 train cost=1.966665327 test cost=1.774208748
# Epoch: 0028 train cost=1.957158220 test cost=1.769111675
# Epoch: 0029 train cost=1.948525043 test cost=1.764479564
# Epoch: 0030 train cost=1.942903806 test cost=1.760219729
# Epoch: 0031 train cost=1.933311115 test cost=1.756097806
# Epoch: 0032 train cost=1.927043824 test cost=1.752591810
# Epoch: 0033 train cost=1.920567866 test cost=1.748794533
# Epoch: 0034 train cost=1.913097539 test cost=1.745810152
# Epoch: 0035 train cost=1.904107047 test cost=1.742667753
# Epoch: 0036 train cost=1.901024159 test cost=1.739386559
# Epoch: 0037 train cost=1.896311224 test cost=1.736637149
# Epoch: 0038 train cost=1.890058039 test cost=1.734041827
# Epoch: 0039 train cost=1.883977618 test cost=1.731329466
# Epoch: 0040 train cost=1.881062343 test cost=1.728922890
# Epoch: 0041 train cost=1.873078455 test cost=1.726451535
# Epoch: 0042 train cost=1.869785947 test cost=1.724073367
# Epoch: 0043 train cost=1.864986555 test cost=1.722060303
# Epoch: 0044 train cost=1.861989225 test cost=1.719989790
# Epoch: 0045 train cost=1.858242225 test cost=1.717734453
# Epoch: 0046 train cost=1.850248988 test cost=1.715536453
# Epoch: 0047 train cost=1.849754245 test cost=1.713534626
# Epoch: 0048 train cost=1.845349133 test cost=1.711377281
# Epoch: 0049 train cost=1.839582539 test cost=1.709249343
# Epoch: 0050 train cost=1.836609391 test cost=1.707372413
# Accuracy: 0.8042

# %%
h1_w = w['h1'].flatten().reshape(-1,1)
h2_w = w['h2'].flatten().reshape(-1,1)
out_w = w['out'].flatten().reshape(-1,1)


fig = plt.figure()
plt.subplot(1, 3, 1)
plt.title("Weight matrix")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Weight matrix ")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Weight matrix ")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
# plt.show()
# Out:
# Text(0.5, 0, 'Output Layer ')
